# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/practice-lab-starter/blob/main/practice.ipynb)

# %% [markdown]
# TODO: Click on the badge above, then `Copy to Drive` before continuing.

# %% [markdown]
# TODO: double click and replace this text with your name

# %% [markdown]
# # Practice Lab
#
# ---
#
# This is a Python Notebook. In this practice lab, you will become familiar with how notebooks work in Google Colab. Read and try everything below. Work with your group to figure out what all the components do!
#
# ## Learning Outcomes
#
# By completing this practice lab you will
#
# - edit markdown
# - recognize python code
# - recognize python comments
# - modify a url to your work
# - update a GitHub Repository
# - check gatorgrade in GitHub Actions
#
# ## Quick Links
#
# - [Starter Repo](https://github.com/allegheny-college-cmpsc-105-spring-2026/practice-lab-starter)
# - [Token Request Form](https://docs.google.com/forms/d/e/1FAIpQLSf9PWdus_ht_E-z99Ski3fJaicmyUVNVWA7xE7kqvFisrMvXg/viewform?usp=sharing&ouid=103917440767036558099)
# - [Discord Channel](https://discord.gg/XxrsVXhS)
# - [TL Office Hours](https://www.cis.allegheny.edu/teaching/technicalleaders/)
#
# ## TODOS
#
# Please read and try everything. In a few locations you will notice the word, "TODO". In those particular locations, feel free to experiment, but also make sure to do what is requested. After the request is complete, you can delete the "TODO" marker.

# %% [markdown]
# ### What are notebooks?
#
# Notebooks can run code and display results. They are often used for data explorations beacuse they are easy to edit and run in segments. The segments are called cells.

# %% [markdown]
# #### Code
#
# You can press shift+ENTER to *run* a cell and go on to the next one. You can also edit the code and run it again to see how the output changes.
#
# You'll see a popup window the first time saying "Warning". Don't worry, it's safe. Click on "run anyway".
#
# Try running the following cells by pressing SHIFT and ENTER (at the same time) for each one.
#
# If you don't see any code cells, you may have to expland them by clicking in the gray area.
#
# *You won't hurt anything by experimenting. If you break it, close the tab and open the activity again to start over.*

# %%
# Click on this cell. Then, press SHIFT and ENTER at the same time.
2+2

# %%
# This is called a "comment". It's a message to other humans.
# Starting with # tells the program not to read this line.
# the program will run the next line since it doesn't start with #
5-4

# %%
# the following lines define variables called "a" and "b"
a = 4
b = 3

# the next line shows us what a plus b is.
a+b

# %%
c = a*a # this line calculates a times a and saves the result as a varialbe called "c"
c       # this line tells the program to show us what "c" is.

# %%
# this coding language is called "python"
d = "I just coded in Python" # yep you did!
d

# %% [markdown]
# Try editing some of the code above.
#
# - TODO: Edit some code to do a different calculation, the rerun the cell
# - TODO: Add a comment somewhere, then rerun the cell
#
# You can run a cell again by pressing shift+ENTER.

# %%
# Can you figure out what ** does?
e = b**a
e

# %% [markdown]
# #### Markdown
#
# The cells above are *code cells* that let you to run code. This is a *markdown cell* that contains markdown text. That's text that isn't read as Python code. Instead, you can format markdown text to look nice.
#
# Double-click on this cell to see the markdown text underneath. Running a markdown cell turns it into pretty, formatted text.
# - here's a bullet point
# - and another list item in *italics* and **bold**.
# - this is a hyperlink to [something on the web](https://www.heavy.ai/learn/data-exploration)
# - You can even embed images
# ![cat](https://www.comfortzone.com/-/media/Project/OneWeb/ComfortZone/Images/Blog/bringing-new-kitten-home.jpg)
#
# #### TODO
#
# Double-click on this cell to see the code that formats this text. Make a few edits and press shift+ENTER to see the changes.
#
# Read more about [formatting the markdown text](https://help.github.com/articles/basic-writing-and-formatting-syntax/).

# %% [markdown]
# #### Summary
#
# Python notebooks can contain both code and formatted text. They are easy to edit, and useful for data explorations which might need a lot of small adjustments and edits to find interesting things in the data.
#
# [Some materials above were borrowed from this reference.](https://colab.research.google.com/github/adamlamee/CODINGinK12/blob/master/notebooks/intro.ipynb)

# %% [markdown]
# ### What does Colab do?
#
# Now that you have an idea of what notebooks are, lets talk about Google Colab interface. Google Colab is able to run python notebooks. It also has many helpful features exploration, organization, and validation.

# %% [markdown]
# #### Document Outline
#
# Colab will show you the document outline. Click on the menu button on the left side of the screen to open and close the document outline.

# %% [markdown]
# #### Variable Explorer
#
# Colab will show you all python objects that you have put in memory by running code cells. Click on the `{x}` button on the left side of the screen to see all the python objects and their values. You can hover or click on the Name to see more information about each object.
#
# Notice that the objects do not get cleared between running code cells. The objects in memory stay in memory cell to cell!

# %% [markdown]
# #### File Browser
#
# Colab will let you access files from a number of different locations. Click on the little folder icon :folder on the left side of the screen to see how you can, for example, upload a file directly from your laptop. This is extremely helpful when you need to load data into a notebook from an external file.

# %% [markdown]
# # TODOs

# %% [markdown]
# ## TODO: Insert a code cell below this cell
#
# - TODO: Inside the code cell, multiply two numbers together, then display the result.
# - TODO: Write a python comment that explains what you did above the code.
# - TODO: Run the cell

# %% [markdown]
# ## TODO: Run the pre-coded code cell below

# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with pyplot")
plt.show()

# source: https://jupyter.org/try-jupyter/notebooks/?path=notebooks/Intro.ipynb

# %% [markdown]
# #### Data Explanation
#
# This data represents randomized numbers on a graph, with different sizes showing generalized area of numbers around that area being picked in a similar location.

# %% [markdown]
# - TODO: The plot above is made with random data, but with your group, brainstorm about what this could be plausibly showing.
# - TODO: Make a text cell below and write out your explanation.
#   - TODO: In the text cell, be sure to include at least one markdown heading
#   - TODO: In the text cell, be sure to include at least one markdown list
#   - TODO: In the text cell, be sure to describe what the x axis, y axis, and colors, and sizes represent

# %% [markdown]
# ## TODO: Post Something in Discord
#
# If you really like the story that you and your colleagues just created about the random data, you could post that, tagging your colleagues. If you have a question, please post it! If you have an answer to a question that you see someone else posted in Discord, feel free to answer.
#
# By the way, did you know that Discord also uses markdown syntax? So everything that you have just learned about markdown formatting can be done in Discord!

# %% [markdown]
# ## TODO: Saving Your Work
#
# Saving your work and making it accessible is a required part of all labs.
#
# ### Accessability part
#
# Make sure that all cells have been executed and are SHOWING their outputs.
#
# In order to make this file accessible you will have to edit the very top badge that looks like this: ![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg).
#
# - Double click next to the top badge to take a look at the urls inside.
# - You should see this: `https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/practice-lab-starter/blob/main/practice.ipynb`
# - Change the word `starter` to your github user name.
#
# ### Saving
#
# This notebook is running on a distant Google server and deletes what you've done when you close this tab. To save your work for later use or analysis you have a few options:
#
# - 'Copy to Drive' button will save it to you Google Drive in a folder called "Colaboratory". You can run it later from there.
# - File > "Save a copy in Drive" will save it to you Google Drive in a folder called "Colaboratory". You can run it later from there.
# - File > "Download .ipynb" to save to your computer (and run with Jupyter software later)
# - Save an image to your computer of a graph or chart, right-click on it and select Save Image as ...
#
# I would recommend a workflow of `Copy to Drive --> editing/running/testing --> downloading`. You should have already hit `Copy to Drive`, but if you haven't, then please do so now. Then go ahead and download the file.
#
# When you are downloading the file, it is crucial that you keep the file name as it was originally. It was originally `practice.ipynb`. Be sure to use the original name when you are prompted!
#
# If the original name is not used, then the file will not be easily accessible and will impact your grade.
#
# ### Accessibility part 2
#
# If you are satisfied with your work, you can now upload the downloaded file to your GitHub repo!
#
# - New students should use GitHub to upload the file.
#   - Next to the green code button in GitHub, you will see an `add file` button. Click that, then choose the downloaded notebook from your computer.
# - If you know what `git` is, you may use it.

# %% [markdown]
# ## TODO: Checking Your Work
#
# ### Check your file output
#
# Once your file is uploaded, please open it on GitHub. All the outputs and plots should be showing. If they are not showing, this means that not all code cells were executed before you downloaded your file.
#
# ### Check your badge
#
# Check that the badge is working by clicking on it. It should take you into Google Colab with **your** file (not the starter file).
#
# ### Check GitHub Actions
#
# Back in GitHub, go to the Actions tab. Click on the top Action to see a report about your TODOs. If the TODOs have been done and deleted, then the actions  will show that gatorgrade reports 100%. This is not your grade, but it is a good indication that you did not forget to do something.
#
# If you see remaining TODOs, then you may want to edit and update your file.
