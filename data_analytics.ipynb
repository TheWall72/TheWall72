# %% [raw]
# ---
# format:
#   html:
#     code-fold: false
# jupyter: python3
# ---

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/data-analytics-starter/blob/main/data_analytics.ipynb)

# %%
# load pre-existing tools available for data exploration

import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact # pre existing code for interaction

# %%
# : Upload your downloaded CSV files to this Colab environment

# Do this by going over to the file icon on the left. Then, toward
# the top, find the file upload icon and upload your csv files.

# NOTE: the CSV file must have the exact names data_survey.csv and data_analytics.csv

# %%
# data_analytics.csv

# TODO: update the column names to match the names you have in your csv file for data_analytics

# create a pandas dataframe
dfa = pd.read_csv(
    '/content/data_analytics.csv',
    sep=',',
    names = ['Nth Day','Average engagement time per active user'],
    skiprows=1
)

# Display the first few rows of the DataFrame
print(dfa.head())
# Out:
#    Nth Day  Average engagement time per active user
# 0        0                                      0.0
# 1        1                                      0.0
# 2        2                                      0.0
# 3        3                                      0.0
# 4        4                                      0.0

# %%
# data_survey.csv

# TODO: update the column names to match the names you have in your csv file for data_survey

# create a pandas dataframe
dfs = pd.read_csv(
    '/content/data_survey.csv',
    sep=',',
    names = ['Timestamp','Score','Do You Do Video Games','Which House Is Better'],
    skiprows=1
)

# Display the first few rows of the DataFrame
print(dfs.head())
# Out:
#             Timestamp  Score Do You Do Video Games Which House Is Better
# 0  3/17/2026 14:57:43    NaN                   Yes                  Delt
# 1  3/17/2026 15:02:59    NaN                   Yes                  Delt
# 2  3/17/2026 15:08:18    NaN                   Yes               Phi Psi
# 3  3/17/2026 15:09:55    NaN                   Yes            Basketball
# 4  3/17/2026 15:14:31    NaN                   Yes               Phi Psi

# %%
# : how many rows and columns are in the dataframe dfa?
#  There are 2 rows and 10 columnsin dfa
# : how many rows and columns are in the dataframe dfs?
# There are 9 rows and 4 columns in dfs

# %%
from numpy import histogram
# Analytics
plt.figure(figsize=(10, 7))
# : Do one or more explorations with dfa
# no interaction is required
days = dfa['Nth Day']
day = dfa['Nth Day']
time = dfa['Average engagement time per active user']
# make a blank canvas


# make a title starting with 'Figure 1:' Fill in a relevant title
plt.title('Figure 1: Engagement Time By Users Over 2 weeks')
# plot
plt.bar(day,time)
plt.xticks = dfa['Nth Day'].value_counts()
# ylabel
plt.ylabel("Time (seconds)")
# xlabel
plt.xlabel('Day')
# ylim

plt.xlim(0,30)
# etc.
plt.tight_layout()
# reveal everything
plt.show()

# %%
from typing import ParamSpecArgs
# Survey

# TODO: Do one or more explorations with dfs
# no interaction is required
counts = dfs['Which House Is Better'].value_counts()

# make a blank canvas

# make a title starting with 'Figure 2:' Fill in a relevant title
plt.title('Figure 2: Who favors which house for parties')

# plot

plt.bar(counts.index, counts.values, color=['#534AB7', '#1D9E75', '#D85A30'])

# ylabel
plt.ylabel('Vote Count')
# xlabel
plt.xlabel('Party House Type')
# ylim
plt.ylim(0,8)
# etc.
plt.tight_layout()
# reveal everything
plt.tight_layout()
plt.show()

# %%
# When you are satisfied with your figures, write up your report in the file called report.qmd
